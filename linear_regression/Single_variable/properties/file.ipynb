# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
csv_data = pd.read_csv("homeprices.csv")
csv_data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
rg = linear_model.LinearRegression()
rg.fit(csv_data[['area']], csv_data.price)
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel("area (sq ft)")
plt.ylabel("price (USD)")
plt.scatter(csv_data.area, csv_data.price, color = "red", marker = "+")
plt.plot(csv_data.area, rg.predict(csv_data[['area']]), color = "blue")

# %%
csv_areas = pd.read_csv("areas.csv")
#csv_areas = csv_areas.head(3)

# %%
rg.predict(csv_areas)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
# %matplotlib inline
plt.xlabel("area (sq ft)")
plt.ylabel("price (USD)")
plt.scatter(csv_data.area, csv_data.price, color = "red", marker = "+")
plt.scatter(csv_areas, rg.predict(csv_areas), color = "green")
plt.plot(csv_data.area, rg.predict(csv_data[['area']]), color = "blue")
